# %% [markdown]
# #This code adds sentimentiment analysis to the dataset with mood

# %%
import pandas as pd
from sklearn.cluster import KMeans

# %%
df_sent=pd.read_csv('/content/drive/MyDrive/df_comb_v5m.csv')

# %%
from textblob import TextBlob
df_sent["Sentiment"] = df_sent["clean lyric"].apply(lambda x:
                   TextBlob(x).sentiment.polarity)
df_sent
# Out:
#        Unnamed: 0                      id                     name  \
# 0               0  6tDDoYIxWvMLTdKpjFkc1B                telepatía
# 1               1  1XXimziG1uhM0eDNCZCrUl                       Up
# 2               2  35mvY5S1H3J2QZyna3TFe0                positions
# 3               3  4u4NyuceXP7Uzh7XFJKCr1                  Hold On
# 4               4  1tkg4EHVoqnhR6iFEXb60y  What You Know Bout Love
# ...           ...                     ...                      ...
# 24087       24087  05g9PYRBd4oE8vMyZBfaqn    Organ Grinder's Swing
# 24088       24088  6VLq2UxSYLMX5tXRH8t5QO            Gloomy Sunday
# 24089       24089  0I3vRKxS2OlqVkpKSaKTRk          Look At Her Now
# 24090       24090  43H6Jrn6CIa7xnfKL79vE6         This Time Around
# 24091       24091  6LYlGeAUMw6CkSv99gzAsk                    Press
#
#        popularity  duration_ms  explicit          artists  \
# 0              97       160191         0       kali uchis
# ...

# %%
# checking for empty values
pd.isnull(df_sent).sum()
# Out:
# Unnamed: 0              0
# id                      0
# name                    0
# popularity              0
# duration_ms             0
# explicit                0
# artists                 0
# id_artists              0
# release_date            0
# danceability            0
# energy                  0
# key                     0
# loudness                0
# mode                    0
# speechiness             0
# acousticness            0
# instrumentalness        0
# liveness                0
# valence                 0
# tempo                   0
# time_signature          0
# SLink                   0
# Lyric                   0
# language              393
# Genres                  0
# clean lyric             0
# mood                11636
# Sentiment               0
# dtype: int64

# %%
df_sent.columns
# Out:
# Index(['Unnamed: 0', 'id', 'name', 'popularity', 'duration_ms', 'explicit',
#        'artists', 'id_artists', 'release_date', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'SLink', 'Lyric', 'language', 'Genres', 'clean lyric', 'mood',
#        'Sentiment'],
#       dtype='object')

# %%
df_sent.Sentiment
# Out:
# 0        0.161905
# 1        0.007993
# 2        0.233333
# 3       -0.150000
# 4        0.202614
#            ...
# 24087    0.056250
# 24088   -0.051780
# 24089    0.226805
# 24090    0.235417
# 24091   -0.031428
# Name: Sentiment, Length: 24092, dtype: float64

# %%
df_sent.head
# Out:
# <bound method NDFrame.head of        Unnamed: 0                      id                     name  \
# 0               0  6tDDoYIxWvMLTdKpjFkc1B                telepatía
# 1               1  1XXimziG1uhM0eDNCZCrUl                       Up
# 2               2  35mvY5S1H3J2QZyna3TFe0                positions
# 3               3  4u4NyuceXP7Uzh7XFJKCr1                  Hold On
# 4               4  1tkg4EHVoqnhR6iFEXb60y  What You Know Bout Love
# ...           ...                     ...                      ...
# 24087       24087  05g9PYRBd4oE8vMyZBfaqn    Organ Grinder's Swing
# 24088       24088  6VLq2UxSYLMX5tXRH8t5QO            Gloomy Sunday
# 24089       24089  0I3vRKxS2OlqVkpKSaKTRk          Look At Her Now
# 24090       24090  43H6Jrn6CIa7xnfKL79vE6         This Time Around
# 24091       24091  6LYlGeAUMw6CkSv99gzAsk                    Press
#
#        popularity  duration_ms  explicit          artists  \
# 0              97       160191         0       kali uchis
# ...

# %%
df_sent.to_csv('/content/drive/MyDrive/df_comb_v6sm.csv')

# %%
df_test =pd.read_csv('/content/drive/MyDrive/df_comb_v6sm.csv')

# %%
df_test.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                      id                     name  \
# 0             0           0  6tDDoYIxWvMLTdKpjFkc1B                telepatía
# 1             1           1  1XXimziG1uhM0eDNCZCrUl                       Up
# 2             2           2  35mvY5S1H3J2QZyna3TFe0                positions
# 3             3           3  4u4NyuceXP7Uzh7XFJKCr1                  Hold On
# 4             4           4  1tkg4EHVoqnhR6iFEXb60y  What You Know Bout Love
#
#    popularity  duration_ms  explicit        artists  \
# 0          97       160191         0     kali uchis
# 1          92       156945         1        cardi b
# 2          92       172325         1  ariana grande
# 3          92       170813         0  justin bieber
# 4          91       160000         1      pop smoke
#
#                    id_artists release_date  ...  valence    tempo  \
# 0  ['1U1el3k54VvEUzo3ybLPlM']   2020-12-04  ...    0.553   83.970
# ...
